# %% [markdown]
# # 빈 공간 셈여림 추가하기
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 방법?
# - 피아노 활성화 상태를 추적해 각각의 velocity에 따른 셈여림을 리스트로 만들어 추출한다.
#     - 0.1초마다 셈여림 상태가 필요한가? -> 셈여림 변화 일관성을 측정하기 위해 필요함.
#     - note_on 에 대한 셈여림 과, note_off에 대한 셈여림 추출이 필요해보임.

# %% [markdown]
# ### 미디 데이터에 대한 -> 셈여림 리스트화 시키기

# %%
import pandas as pd

input_file = pd.read_csv('train_data0307.csv')

test_csv.head()
# Out:
#    sec                msg_type channel      note  velocity dynamic  accent  \
# 0  0.0                      []      []        []        []     ppp       0
# 1  0.1  ['note_on', 'note_on']  [0, 0]  [60, 60]  [21, 21]     ppp       0
# 2  0.2                      []      []        []        []     NaN       0
# 3  0.3  ['note_on', 'note_on']  [0, 0]  [64, 64]  [32, 32]     ppp       0
# 4  0.4                      []      []        []        []     NaN       0
#
#    count  main_vol  depth pedal  pan
# 0      0       100      0     0    0
# 1      2         0      0     0    0
# 2      0         0      0     0    0
# 3      2         0      0     0    0
# 4      0         0      0     0    0

# %% [markdown]
# 1. 노트에 대해 리스트가 비었다면 -> x 표시, 만약 전 dynamic이 있다면, 그 값으로 넣어주기.

# %%
def distribute_dynamic(mean_velocity):
    """
    velocity에 따른 dynamic 기호 추출
    """
    dynamic = ''
    if 0 <= mean_velocity < 36:
        dynamic = 'ppp'
    elif 36 <= mean_velocity < 49:
        dynamic = 'pp'
    elif 49 <= mean_velocity < 62:
        dynamic = 'p'
    elif 62 <= mean_velocity < 75:
        dynamic = 'mp'
    elif 75 <= mean_velocity < 88:
        dynamic = 'mf'
    elif 88 <= mean_velocity < 101:
        dynamic = 'f'
    elif 101 <= mean_velocity < 114:
        dynamic = 'ff'
    elif 114 <= mean_velocity <= 127:
        dynamic = 'fff'
    
    return dynamic

# %%
def add_new_dynamic_to_dataframe(input_file, target_file):
    """
    비어있는 dynamic 기호를 추가한다.
    1. note_on에 대한 dynamic 기호만 반영함.
        - dynamic 추가 방법
        1. 피아노 0.1초마다 note_on_status 값을 추출한다.
        2. 0.1 초에 해당하는 note_on 항목 중 velocity의 최대 값에 기반해 기호를 추출함.
    """
    input_file_note_status = [[{'note': x}, {'status': False}, {'velocity' : 0}] for x in range(128)]
    target_file_note_status = [[{'note': x}, {'status': False}, {'velocity' : 0}] for x in range(128)]

    input_dynamic_list = []
    target_dynamic_list = []
    
    # 인풋 데이터에 대해서 수행.
    for index in range(len(input_file)):

            target_temp_data = []

            notes_input = eval(input_file.at[index, 'note']) # 문자열을 -> 숫자로
            msg_type_input = eval(input_file.at[index, 'msg_type']) # 문자열을 -> 숫자로
            velocity = eval(input_file.at[index, 'velocity'])

            temp = list(zip(notes_input, msg_type_input, velocity)) # [(60, 'note_on'), (60, 'note_on')] 이와 같이 데이터 수정

            # 피아노 활성화 값 추적 
            for data in temp:
                if data[1] == 'note_on':
                    input_file_note_status[data[0]][1]['status'] = True
                    print('velo: ', data[2])
                    input_file_note_status[data[0]][2]['velocity'] = data[2]
                elif data[1] == 'note_off':
                    input_file_note_status[data[0]][1]['status'] = False
                    input_file_note_status[data[0]][2]['velocity'] = data[2]

            print('index:', index)

            velocity_list = []

            for on_data in input_file_note_status:
                if on_data[1]['status'] == True:
                    velocity_list.append(({'note': on_data[0]['note']}, {'velocity' : on_data[2]['velocity']}))
            print(velocity_list)

            max_velocity = 0 # 최대 값 찾기

            for velocity in velocity_list:
                # 최대값 찾기
                if max_velocity < velocity[1]['velocity']:
                    max_velocity = velocity[1]['velocity']
            dynamic = distribute_dynamic(max_velocity)
            print('현재 인덱스의 셈여림 기호는 : ', dynamic)
            dynamic_list.append(dynamic)
            print()
            print('=='*50)
    
    # 타겟 데이터에 대해 수행
    
    print(dynamic_list)
    input_file.insert(loc=5, column='new_dynamic', value=dynamic_list)
# Out:
# index: 0
# []
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  21
# velo:  21
# index: 1
# [({'note': 60}, {'velocity': 21})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 2
# [({'note': 60}, {'velocity': 21})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  32
# velo:  32
# index: 3
# [({'note': 60}, {'velocity': 21}), ({'note': 64}, {'velocity': 32})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 4
# [({'note': 60}, {'velocity': 21}), ({'note': 64}, {'velocity': 32})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  34
# velo:  34
# index: 5
# [({'note': 60}, {'velocity': 21}), ({'note': 64}, {'velocity': 32}), ({'note': 67}, {'velocity': 34})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 6
# [({'note': 60}, {'velocity': 21}), ({'note': 64}, {'velocity': 32}), ({'note': 67}, {'velocity': 34})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  34
# velo:  34
# index: 7
# [({'note': 60}, {'velocity': 21}), ({'note': 64}, {'velocity': 32}), ({'note': 72}, {'velocity': 34})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 8
# [({'note': 60}, {'velocity': 21}), ({'note': 64}, {'velocity': 32}), ({'note': 72}, {'velocity': 34})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 9
# [({'note': 60}, {'velocity': 21}), ({'note': 64}, {'velocity': 32}), ({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 10
# [({'note': 60}, {'velocity': 21}), ({'note': 64}, {'velocity': 32}), ({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  38
# velo:  38
# index: 11
# [({'note': 60}, {'velocity': 21}), ({'note': 64}, {'velocity': 32}), ({'note': 67}, {'velocity': 38}), ({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 12
# [({'note': 64}, {'velocity': 32}), ({'note': 67}, {'velocity': 38})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  36
# velo:  36
# index: 13
# [({'note': 72}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 14
# [({'note': 72}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 15
# [({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 16
# [({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  35
# velo:  35
# index: 17
# [({'note': 60}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 18
# [({'note': 60}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  31
# velo:  31
# index: 19
# [({'note': 60}, {'velocity': 35}), ({'note': 64}, {'velocity': 31})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 20
# [({'note': 60}, {'velocity': 35}), ({'note': 64}, {'velocity': 31})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  42
# velo:  42
# index: 21
# [({'note': 60}, {'velocity': 35}), ({'note': 64}, {'velocity': 31}), ({'note': 67}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 22
# [({'note': 60}, {'velocity': 35}), ({'note': 64}, {'velocity': 31}), ({'note': 67}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 23
# [({'note': 60}, {'velocity': 35}), ({'note': 64}, {'velocity': 31}), ({'note': 67}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 24
# [({'note': 60}, {'velocity': 35}), ({'note': 64}, {'velocity': 31}), ({'note': 72}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 25
# [({'note': 60}, {'velocity': 35}), ({'note': 64}, {'velocity': 31}), ({'note': 72}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  53
# velo:  53
# index: 26
# [({'note': 60}, {'velocity': 35}), ({'note': 64}, {'velocity': 31}), ({'note': 76}, {'velocity': 53})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 27
# [({'note': 60}, {'velocity': 35}), ({'note': 64}, {'velocity': 31}), ({'note': 76}, {'velocity': 53})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  38
# velo:  38
# index: 28
# [({'note': 60}, {'velocity': 35}), ({'note': 64}, {'velocity': 31}), ({'note': 67}, {'velocity': 38}), ({'note': 76}, {'velocity': 53})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 29
# [({'note': 60}, {'velocity': 35}), ({'note': 64}, {'velocity': 31}), ({'note': 67}, {'velocity': 38})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  42
# velo:  42
# index: 30
# [({'note': 60}, {'velocity': 35}), ({'note': 64}, {'velocity': 31}), ({'note': 67}, {'velocity': 38}), ({'note': 72}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 31
# [({'note': 72}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  55
# velo:  55
# index: 32
# [({'note': 76}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 33
# [({'note': 76}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 34
# [({'note': 60}, {'velocity': 40}), ({'note': 76}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 35
# [({'note': 60}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 36
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 37
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  53
# velo:  53
# index: 38
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 40}), ({'note': 69}, {'velocity': 53})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 39
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 40}), ({'note': 69}, {'velocity': 53})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  51
# velo:  51
# index: 40
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 40}), ({'note': 69}, {'velocity': 53}), ({'note': 74}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 41
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 40}), ({'note': 74}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 42
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 40}), ({'note': 74}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  53
# velo:  53
# index: 43
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 40}), ({'note': 77}, {'velocity': 53})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 44
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 40}), ({'note': 77}, {'velocity': 53})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  51
# velo:  51
# index: 45
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 40}), ({'note': 69}, {'velocity': 51}), ({'note': 77}, {'velocity': 53})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 46
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 40}), ({'note': 69}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  44
# velo:  44
# index: 47
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 40}), ({'note': 69}, {'velocity': 51}), ({'note': 74}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 48
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 40}), ({'note': 74}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  48
# velo:  48
# index: 49
# [({'note': 62}, {'velocity': 40}), ({'note': 77}, {'velocity': 48})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 50
# [({'note': 77}, {'velocity': 48})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 51
# [({'note': 60}, {'velocity': 46}), ({'note': 77}, {'velocity': 48})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 52
# [({'note': 60}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 53
# [({'note': 60}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  36
# velo:  36
# index: 54
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 55
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  51
# velo:  51
# index: 56
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 69}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 57
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 69}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  42
# velo:  42
# index: 58
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 69}, {'velocity': 51}), ({'note': 74}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 59
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 74}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  53
# velo:  53
# index: 60
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 77}, {'velocity': 53})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 61
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 77}, {'velocity': 53})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  34
# velo:  34
# index: 62
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 69}, {'velocity': 34}), ({'note': 77}, {'velocity': 53})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 63
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 69}, {'velocity': 34})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 64
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 69}, {'velocity': 34})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 65
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 74}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 66
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 74}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 67
# [({'note': 77}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 68
# [({'note': 77}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  27
# velo:  27
# index: 69
# [({'note': 59}, {'velocity': 27})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 70
# [({'note': 59}, {'velocity': 27})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  32
# velo:  32
# index: 71
# [({'note': 59}, {'velocity': 27}), ({'note': 62}, {'velocity': 32})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 72
# [({'note': 59}, {'velocity': 27}), ({'note': 62}, {'velocity': 32})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 73
# [({'note': 59}, {'velocity': 27}), ({'note': 62}, {'velocity': 32})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  51
# velo:  51
# index: 74
# [({'note': 59}, {'velocity': 27}), ({'note': 62}, {'velocity': 32}), ({'note': 67}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 75
# [({'note': 59}, {'velocity': 27}), ({'note': 62}, {'velocity': 32}), ({'note': 67}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 76
# [({'note': 59}, {'velocity': 27}), ({'note': 62}, {'velocity': 32}), ({'note': 67}, {'velocity': 51}), ({'note': 74}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 77
# [({'note': 59}, {'velocity': 27}), ({'note': 62}, {'velocity': 32}), ({'note': 74}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  51
# velo:  51
# index: 78
# [({'note': 59}, {'velocity': 27}), ({'note': 62}, {'velocity': 32}), ({'note': 77}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 79
# [({'note': 59}, {'velocity': 27}), ({'note': 62}, {'velocity': 32}), ({'note': 77}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 80
# [({'note': 59}, {'velocity': 27}), ({'note': 62}, {'velocity': 32}), ({'note': 67}, {'velocity': 40}), ({'note': 77}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 81
# [({'note': 59}, {'velocity': 27}), ({'note': 62}, {'velocity': 32}), ({'note': 67}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 82
# [({'note': 59}, {'velocity': 27}), ({'note': 62}, {'velocity': 32}), ({'note': 67}, {'velocity': 40}), ({'note': 74}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 83
# [({'note': 59}, {'velocity': 27}), ({'note': 62}, {'velocity': 32}), ({'note': 74}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 84
# [({'note': 77}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 85
# [({'note': 77}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 86
# [({'note': 59}, {'velocity': 46}), ({'note': 77}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 87
# [({'note': 59}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  36
# velo:  36
# index: 88
# [({'note': 59}, {'velocity': 46}), ({'note': 62}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 89
# [({'note': 59}, {'velocity': 46}), ({'note': 62}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 90
# [({'note': 59}, {'velocity': 46}), ({'note': 62}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  51
# velo:  51
# index: 91
# [({'note': 59}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 67}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 92
# [({'note': 59}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 67}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  42
# velo:  42
# index: 93
# [({'note': 59}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 67}, {'velocity': 51}), ({'note': 74}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 94
# [({'note': 59}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 74}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 95
# [({'note': 59}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 77}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 96
# [({'note': 59}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 77}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 97
# [({'note': 59}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 67}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 98
# [({'note': 59}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 67}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  42
# velo:  42
# index: 99
# [({'note': 59}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 67}, {'velocity': 46}), ({'note': 74}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 100
# [({'note': 59}, {'velocity': 46}), ({'note': 62}, {'velocity': 36}), ({'note': 74}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  44
# velo:  44
# index: 101
# [({'note': 74}, {'velocity': 42}), ({'note': 77}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 102
# [({'note': 77}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 103
# [({'note': 60}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 104
# [({'note': 60}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 105
# [({'note': 60}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  36
# velo:  36
# index: 106
# [({'note': 60}, {'velocity': 40}), ({'note': 64}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 107
# [({'note': 60}, {'velocity': 40}), ({'note': 64}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  35
# velo:  35
# index: 108
# [({'note': 60}, {'velocity': 40}), ({'note': 64}, {'velocity': 36}), ({'note': 67}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 109
# [({'note': 60}, {'velocity': 40}), ({'note': 64}, {'velocity': 36}), ({'note': 67}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 110
# [({'note': 60}, {'velocity': 40}), ({'note': 64}, {'velocity': 36}), ({'note': 72}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 111
# [({'note': 60}, {'velocity': 40}), ({'note': 64}, {'velocity': 36}), ({'note': 72}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 112
# [({'note': 60}, {'velocity': 40}), ({'note': 64}, {'velocity': 36}), ({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 113
# [({'note': 60}, {'velocity': 40}), ({'note': 64}, {'velocity': 36}), ({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 114
# [({'note': 60}, {'velocity': 40}), ({'note': 64}, {'velocity': 36}), ({'note': 67}, {'velocity': 46}), ({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 115
# [({'note': 60}, {'velocity': 40}), ({'note': 64}, {'velocity': 36}), ({'note': 67}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  38
# velo:  38
# index: 116
# [({'note': 60}, {'velocity': 40}), ({'note': 64}, {'velocity': 36}), ({'note': 67}, {'velocity': 46}), ({'note': 72}, {'velocity': 38})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 117
# [({'note': 60}, {'velocity': 40}), ({'note': 64}, {'velocity': 36}), ({'note': 72}, {'velocity': 38})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  44
# velo:  44
# index: 118
# [({'note': 72}, {'velocity': 38}), ({'note': 76}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 119
# [({'note': 76}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  42
# velo:  42
# index: 120
# [({'note': 60}, {'velocity': 42}), ({'note': 76}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 121
# [({'note': 60}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 122
# [({'note': 60}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  27
# velo:  27
# index: 123
# [({'note': 60}, {'velocity': 42}), ({'note': 64}, {'velocity': 27})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 124
# [({'note': 60}, {'velocity': 42}), ({'note': 64}, {'velocity': 27})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  44
# velo:  44
# index: 125
# [({'note': 60}, {'velocity': 42}), ({'note': 64}, {'velocity': 27}), ({'note': 67}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 126
# [({'note': 60}, {'velocity': 42}), ({'note': 64}, {'velocity': 27}), ({'note': 67}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 127
# [({'note': 60}, {'velocity': 42}), ({'note': 64}, {'velocity': 27}), ({'note': 72}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 128
# [({'note': 60}, {'velocity': 42}), ({'note': 64}, {'velocity': 27}), ({'note': 72}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 129
# [({'note': 60}, {'velocity': 42}), ({'note': 64}, {'velocity': 27}), ({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 130
# [({'note': 60}, {'velocity': 42}), ({'note': 64}, {'velocity': 27}), ({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  44
# velo:  44
# index: 131
# [({'note': 60}, {'velocity': 42}), ({'note': 64}, {'velocity': 27}), ({'note': 67}, {'velocity': 44}), ({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 132
# [({'note': 60}, {'velocity': 42}), ({'note': 64}, {'velocity': 27}), ({'note': 67}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  44
# velo:  44
# index: 133
# [({'note': 60}, {'velocity': 42}), ({'note': 64}, {'velocity': 27}), ({'note': 67}, {'velocity': 44}), ({'note': 72}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 134
# [({'note': 64}, {'velocity': 27}), ({'note': 72}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  38
# velo:  38
# index: 135
# [({'note': 72}, {'velocity': 44}), ({'note': 76}, {'velocity': 38})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 136
# [({'note': 76}, {'velocity': 38})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  53
# velo:  53
# index: 137
# [({'note': 60}, {'velocity': 53}), ({'note': 76}, {'velocity': 38})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 138
# [({'note': 60}, {'velocity': 53})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 139
# [({'note': 60}, {'velocity': 53})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  35
# velo:  35
# index: 140
# [({'note': 60}, {'velocity': 53}), ({'note': 64}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 141
# [({'note': 60}, {'velocity': 53}), ({'note': 64}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  51
# velo:  51
# index: 142
# [({'note': 60}, {'velocity': 53}), ({'note': 64}, {'velocity': 35}), ({'note': 69}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 143
# [({'note': 60}, {'velocity': 53}), ({'note': 64}, {'velocity': 35}), ({'note': 69}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 144
# [({'note': 60}, {'velocity': 53}), ({'note': 64}, {'velocity': 35}), ({'note': 69}, {'velocity': 51}), ({'note': 76}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 145
# [({'note': 60}, {'velocity': 53}), ({'note': 64}, {'velocity': 35}), ({'note': 76}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  57
# velo:  57
# index: 146
# [({'note': 60}, {'velocity': 53}), ({'note': 64}, {'velocity': 35}), ({'note': 81}, {'velocity': 57})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 147
# [({'note': 60}, {'velocity': 53}), ({'note': 64}, {'velocity': 35}), ({'note': 81}, {'velocity': 57})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 148
# [({'note': 60}, {'velocity': 53}), ({'note': 64}, {'velocity': 35}), ({'note': 81}, {'velocity': 57})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  48
# velo:  48
# index: 149
# [({'note': 60}, {'velocity': 53}), ({'note': 64}, {'velocity': 35}), ({'note': 69}, {'velocity': 48})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 150
# [({'note': 60}, {'velocity': 53}), ({'note': 64}, {'velocity': 35}), ({'note': 69}, {'velocity': 48})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  36
# velo:  36
# index: 151
# [({'note': 60}, {'velocity': 53}), ({'note': 64}, {'velocity': 35}), ({'note': 76}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 152
# [({'note': 64}, {'velocity': 35}), ({'note': 76}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  55
# velo:  55
# index: 153
# [({'note': 81}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 154
# [({'note': 81}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  38
# velo:  38
# index: 155
# [({'note': 60}, {'velocity': 38}), ({'note': 81}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 156
# [({'note': 60}, {'velocity': 38})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 157
# [({'note': 60}, {'velocity': 38})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  35
# velo:  35
# index: 158
# [({'note': 60}, {'velocity': 38}), ({'note': 64}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 159
# [({'note': 60}, {'velocity': 38}), ({'note': 64}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 160
# [({'note': 60}, {'velocity': 38}), ({'note': 64}, {'velocity': 35}), ({'note': 69}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 161
# [({'note': 60}, {'velocity': 38}), ({'note': 64}, {'velocity': 35}), ({'note': 69}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 162
# [({'note': 60}, {'velocity': 38}), ({'note': 64}, {'velocity': 35}), ({'note': 69}, {'velocity': 40}), ({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 163
# [({'note': 60}, {'velocity': 38}), ({'note': 64}, {'velocity': 35}), ({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 164
# [({'note': 60}, {'velocity': 38}), ({'note': 64}, {'velocity': 35}), ({'note': 76}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  51
# velo:  51
# index: 165
# [({'note': 60}, {'velocity': 38}), ({'note': 64}, {'velocity': 35}), ({'note': 81}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 166
# [({'note': 60}, {'velocity': 38}), ({'note': 64}, {'velocity': 35}), ({'note': 81}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  35
# velo:  35
# index: 167
# [({'note': 60}, {'velocity': 38}), ({'note': 64}, {'velocity': 35}), ({'note': 69}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 168
# [({'note': 60}, {'velocity': 38}), ({'note': 64}, {'velocity': 35}), ({'note': 69}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  35
# velo:  35
# index: 169
# [({'note': 60}, {'velocity': 38}), ({'note': 64}, {'velocity': 35}), ({'note': 69}, {'velocity': 35}), ({'note': 76}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 170
# [({'note': 69}, {'velocity': 35}), ({'note': 76}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  57
# velo:  57
# index: 171
# [({'note': 69}, {'velocity': 35}), ({'note': 81}, {'velocity': 57})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 172
# [({'note': 69}, {'velocity': 35}), ({'note': 81}, {'velocity': 57})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 173
# [({'note': 69}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  46
# velo:  46
# index: 174
# [({'note': 60}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 175
# [({'note': 60}, {'velocity': 46})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  38
# velo:  38
# index: 176
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 38})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 177
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 38})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  43
# velo:  43
# index: 178
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 38}), ({'note': 66}, {'velocity': 43})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 179
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 38}), ({'note': 66}, {'velocity': 43})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  34
# velo:  34
# index: 180
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 38}), ({'note': 69}, {'velocity': 34})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 181
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 38}), ({'note': 69}, {'velocity': 34})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  44
# velo:  44
# index: 182
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 38}), ({'note': 69}, {'velocity': 34}), ({'note': 74}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 183
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 38}), ({'note': 74}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  31
# velo:  31
# index: 184
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 38}), ({'note': 66}, {'velocity': 31}), ({'note': 74}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 185
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 38}), ({'note': 66}, {'velocity': 31})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 186
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 38}), ({'note': 66}, {'velocity': 31})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  30
# velo:  30
# index: 187
# [({'note': 60}, {'velocity': 46}), ({'note': 62}, {'velocity': 38}), ({'note': 69}, {'velocity': 30})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 188
# [({'note': 62}, {'velocity': 38}), ({'note': 69}, {'velocity': 30})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  44
# velo:  44
# index: 189
# [({'note': 74}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 190
# [({'note': 74}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 191
# [({'note': 60}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 192
# [({'note': 60}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  31
# velo:  31
# index: 193
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 31})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 194
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 31})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  36
# velo:  36
# index: 195
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 31}), ({'note': 66}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 196
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 31}), ({'note': 66}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 197
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 31}), ({'note': 66}, {'velocity': 36})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  35
# velo:  35
# index: 198
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 31}), ({'note': 69}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 199
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 31}), ({'note': 69}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 200
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 31}), ({'note': 74}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 201
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 31}), ({'note': 74}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  51
# velo:  51
# index: 202
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 31}), ({'note': 66}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 203
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 31}), ({'note': 66}, {'velocity': 51})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  34
# velo:  34
# index: 204
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 31}), ({'note': 69}, {'velocity': 34})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 205
# [({'note': 60}, {'velocity': 40}), ({'note': 62}, {'velocity': 31}), ({'note': 69}, {'velocity': 34})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  42
# velo:  42
# index: 206
# [({'note': 69}, {'velocity': 34}), ({'note': 74}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 207
# [({'note': 74}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 208
# [({'note': 74}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  42
# velo:  42
# index: 209
# [({'note': 59}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 210
# [({'note': 59}, {'velocity': 42})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 211
# ...
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  44
# velo:  44
# index: 1162
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 59}, {'velocity': 44}), ({'note': 62}, {'velocity': 32})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 1163
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 59}, {'velocity': 44})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  35
# velo:  35
# index: 1164
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 59}, {'velocity': 44}), ({'note': 62}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 1165
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 62}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 1166
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 62}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  40
# velo:  40
# index: 1167
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 59}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# index: 1168
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 59}, {'velocity': 40})]
# 현재 인덱스의 셈여림 기호는 :  pp
#
# ====================================================================================================
# velo:  28
# velo:  28
# index: 1169
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 53}, {'velocity': 28})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 1170
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 53}, {'velocity': 28})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  35
# velo:  35
# index: 1171
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 59}, {'velocity': 35})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 1172
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32})]
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  73
# velo:  73
# index: 1173
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 62}, {'velocity': 73})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1174
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 62}, {'velocity': 73})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# velo:  55
# velo:  55
# index: 1175
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 62}, {'velocity': 73}), ({'note': 65}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1176
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 65}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 1177
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 65}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  55
# velo:  55
# index: 1178
# [({'note': 36}, {'velocity': 31}), ({'note': 48}, {'velocity': 32}), ({'note': 64}, {'velocity': 55}), ({'note': 65}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 1179
# [({'note': 64}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# velo:  57
# velo:  57
# index: 1180
# []
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 1181
# []
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 1182
# []
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# index: 1183
# []
# 현재 인덱스의 셈여림 기호는 :  ppp
#
# ====================================================================================================
# velo:  70
# velo:  70
# velo:  46
# velo:  46
# velo:  55
# velo:  55
# velo:  55
# velo:  55
# velo:  36
# velo:  36
# index: 1184
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1185
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1186
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1187
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1188
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1189
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1190
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1191
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1192
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1193
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1194
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1195
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1196
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1197
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1198
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1199
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1200
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1201
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1202
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1203
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 64}, {'velocity': 70}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  mp
#
# ====================================================================================================
# index: 1204
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# index: 1205
# [({'note': 36}, {'velocity': 36}), ({'note': 48}, {'velocity': 46}), ({'note': 67}, {'velocity': 55}), ({'note': 72}, {'velocity': 55})]
# 현재 인덱스의 셈여림 기호는 :  p
#
# ====================================================================================================
# ['ppp', 'ppp', 'ppp', 'ppp', 'ppp', 'ppp', 'ppp', 'ppp', 'ppp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'ppp', 'ppp', 'ppp', 'ppp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'ppp', 'ppp', 'ppp', 'ppp', 'ppp', 'p', 'p', 'p', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'pp', 'pp', 'pp', 'ppp', 'p', 'p', 'ppp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'ppp', 'ppp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'ppp', 'ppp', 'ppp', 'ppp', 'ppp', 'ppp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'ppp', 'ppp', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'pp', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'p', 'pp', 'pp', 'mp', 'mp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'pp', 'ppp', 'ppp', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'p', 'p', 'mp', 'mp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'pp', 'pp', 'p', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'ppp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'p', 'pp', 'pp', 'pp', 'p', 'p', 'p', 'ppp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'ppp', 'ppp', 'ppp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'pp', 'ppp', 'ppp', 'ppp', 'ppp', ' ...

# %%
input_file.head()
# Out:
#    sec                msg_type channel      note  velocity new_dynamic  \
# 0  0.0                      []      []        []        []         ppp
# 1  0.1  ['note_on', 'note_on']  [0, 0]  [60, 60]  [21, 21]         ppp
# 2  0.2                      []      []        []        []         ppp
# 3  0.3  ['note_on', 'note_on']  [0, 0]  [64, 64]  [32, 32]         ppp
# 4  0.4                      []      []        []        []         ppp
#
#   dynamic  accent  count  main_vol  depth pedal  pan
# 0     ppp       0      0       100      0     0    0
# 1     ppp       0      2         0      0     0    0
# 2     NaN       0      0         0      0     0    0
# 3     ppp       0      2         0      0     0    0
# 4     NaN       0      0         0      0     0    0
