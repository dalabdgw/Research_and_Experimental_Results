# %% [markdown]
# ## 비교 내용
#
# |이름|방법|
# |--|--|
# |음정 정확도|방법1. <br> ![image.png](attachment:image.png)<br>방법2<br>점수 = 정확히 친 노트의 개수 / 총 쳐야하는 노트의 개수 x 100|

# %% [markdown]
# # csv - 비교?
#
# ## 데이터 내용
# |종류|sec|tick|bpm|msg_type|channel|note|velocity|dynamic|accent|count|main_vol|depth|pedal|pan|tempo|
# |-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|
# |추출|초|틱?|Bit per Minuate|Note on / Note off|?|0~127|?|셈여림|?|?|?|?|페달?|?|템포?|
# |큐베이스에서 어떤 것에 해당하는지?|옵션에서 Seconds로 음악 데이터를 보면 확인 가능|틱?|Bit per Minuate|Note on / Note off|?|0~127|?|셈여림|?|?|?|?|페달?|?|템포?|
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 큐베이스 상에서 데이터 확대 보기.
# ![image-2.png](attachment:image-2.png)
#
# # 엑셀로 추출한 데이터
# ![image.png](attachment:image.png)
#
# --> 1초에 정확히 노트가 찍힌 것을 볼 수 있음

# %% [markdown]
# # 비교 파일
#
# 1. butterfly_input_data.csv
# 2. butterfly_target_data.csv
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 음정 비교
# ## 방법 1
# ![image.png](attachment:image.png)

# %% [markdown]
# # 데이터 전처리
#
# 1. 음정 비교 -> 중복 제거를 통해 음정 데이터만 확보
# 2. 시간 -> 해당 시간에 음정을 정확히 쳤는가가 중
#     - 두 데이터에 대해서 행(즉, 시간정보 or 틱정보)가 다르다면?
#         - 행간 비교를 통해 정답 데이터에 없는 시간초를 생성 해 채워준다? -> 어차피 못친거니까 감점 요인
#         - 데이터가 밀린 경우에? 전처리 작업 시 도레미파솔라시도를 통해 싱크를 맞춰준다? -> 이미 늦음
#
# |생각|
# |--|
# |2024.01.18 일단 위 아래 중복 제거를 통해 데이터를 간단히|

# %%
import pandas as pd

input_path = './butterfly_input_data.csv'
target_path = './butterfly_target_data.csv'

input_data = pd.read_csv(input_path)
target_data = pd.read_csv(target_path)

# %%
# 데이터 확인해주기
print('input_data')
input_data.head()
# Out:
# input_data
#      sec  tick    bpm msg_type channel note velocity dynamic  accent  count  \
# 0  0.000     0  120.0       []      []   []       []     ppp       0      0
# 1  0.001     1  120.0       []      []   []       []     ppp       0      0
# 2  0.002     2  120.0       []      []   []       []     ppp       0      0
# 3  0.003     3  120.0       []      []   []       []     ppp       0      0
# 4  0.004     4  120.0       []      []   []       []     ppp       0      0
#
#    main_vol  depth  pedal  pan   tempo
# 0       100      0      0   64  500000
# 1       100      0      0   64  500000
# 2       100      0      0   64  500000
# 3       100      0      0   64  500000
# 4       100      0      0   64  500000

# %%
print('target_data')
target_data.head()
# Out:
# target_data
#      sec  tick    bpm msg_type channel note velocity dynamic  accent  count  \
# 0  0.000     0  120.0       []      []   []       []     ppp       0      0
# 1  0.001     1  120.0       []      []   []       []     ppp       0      0
# 2  0.002     2  120.0       []      []   []       []     ppp       0      0
# 3  0.003     3  120.0       []      []   []       []     ppp       0      0
# 4  0.004     4  120.0       []      []   []       []     ppp       0      0
#
#    main_vol  depth  pedal  pan   tempo
# 0       100      0      0   64  500000
# 1       100      0      0   64  500000
# 2       100      0      0   64  500000
# 3       100      0      0   64  500000
# 4       100      0      0   64  500000

# %% [markdown]
# # 데이터 전처리
# - 위 아래 중복 제거
# 1. 위 아래 note 열 값이 같으면 제거

# %%
def ridOfDupRow(midiData):
    for i in range(len(midiData)-1):
        if midiData['note'][i] == midiData['note'][i+1] or midiData['msg_type'][i] == '[]':
            midiData = midiData.drop(i)
    return midiData

# %%
# 확인
input_data = ridOfDupRow(input_data)
target_data = ridOfDupRow(target_data)

# %%
input_data.head()
# Out:
#         sec  tick    bpm                            msg_type    channel  \
# 1199  1.248  1199  120.0                         ['note_on']        [0]
# 1219  1.269  1219  120.0             ['note_off', 'note_on']     [0, 0]
# 1344  1.400  1344  120.0                         ['note_on']        [0]
# 1395  1.453  1395  120.0                        ['note_off']        [0]
# 1473  1.534  1473  120.0  ['note_off', 'note_on', 'note_on']  [0, 0, 0]
#
#               note      velocity dynamic  accent  count  main_vol  depth  \
# 1199          [69]          [75]      mf       0      1         0      0
# 1219      [69, 70]     [64, 100]      mf       0      2         0      0
# 1344          [70]          [68]      mp       0      1         0      0
# 1395          [69]          [64]      mp       0      1         0      0
# 1473  [70, 41, 72]  [64, 86, 87]      mf       1      3         0      0
#
#       pedal  pan   tempo
# 1199      0    0  500000
# 1219      0    0  500000
# 1344      0    0  500000
# 1395      0    0  500000
# 1473      0    0  500000

# %%
target_data.head()
# Out:
#         sec  tick    bpm                            msg_type    channel  \
# 1199  1.248  1199  120.0                         ['note_on']        [0]
# 1439  1.498  1439  120.0             ['note_off', 'note_on']     [0, 0]
# 1919  1.998  1919  120.0  ['note_off', 'note_on', 'note_on']  [0, 0, 0]
# 2399  2.498  2399  120.0                         ['note_on']        [0]
# 2639  2.748  2639  120.0  ['note_off', 'note_on', 'note_on']  [0, 0, 0]
#
#               note      velocity dynamic  accent  count  main_vol  depth  \
# 1199          [69]         [100]       f       1      1         0      0
# 1439      [69, 70]     [64, 100]      mf       0      2         0      0
# 1919  [70, 41, 72]  [64, 86, 87]      mf       0      3         0      0
# 2399          [48]          [91]       f       0      1         0      0
# 2639  [72, 53, 65]  [64, 96, 94]      mf       0      3         0      0
#
#       pedal  pan   tempo
# 1199      0    0  500000
# 1439      0    0  500000
# 1919      0    0  500000
# 2399      0    0  500000
# 2639      0    0  500000

# %%
# 중복 제거한 데이터 프레임 정보 확인
def dataInfo(midiData):
    print('데이터 길이: ', len(midiData))

print(dataInfo(input_data))
print(dataInfo(target_data))
# Out:
# 데이터 길이:  235
# None
# 데이터 길이:  67
# None

# %%
# note 데이터만 가져오기
input_note = input_data['note'].to_list()
target_note = target_data['note'].to_list()

# %%
print(input_note)
print('='*50)
print(target_note)
# Out:
# ['[69]', '[69, 70]', '[70]', '[69]', '[70, 41, 72]', '[72]', '[41]', '[70]', '[72]', '[48]', '[41]', '[53]', '[72, 53, 65]', '[48]', '[65]', '[65, 64]', '[64]', '[53]', '[65]', '[41, 48, 53, 64, 45, 65]', '[45]', '[65]', '[64]', '[65]', '[53]', '[52]', '[45]', '[57]', '[65, 57, 72]', '[52]', '[72]', '[57]', '[72]', '[46]', '[72]', '[45, 53, 57, 72, 46, 72]', '[46]', '[53]', '[72]', '[74]', '[72, 74]', '[74, 58, 70]', '[58]', '[53]', '[70]', '[74]', '[58]', '[70, 69]', '[69]', '[70]', '[46, 53, 58, 69, 48, 70]', '[70]', '[48]', '[69]', '[55]', '[48]', '[60]', '[70]', '[70, 60, 69]', '[69]', '[55]', '[60]', '[70]', '[69, 70]', '[69]', '[48, 55, 60, 70, 41, 72]', '[41]', '[72]', '[70]', '[72]', '[48]', '[41]', '[48]', '[53]', '[65]', '[72, 53, 65]', '[64]', '[65, 64]', '[65]', '[53]', '[45]', '[65]', '[41, 48, 53, 64, 45, 65]', '[64]', '[65]', '[52]', '[53]', '[45]', '[57]', '[65, 57, 69]', '[69]', '[52]', '[57]', '[46]', '[45, 53, 57, 69, 46, 62]', '[62]', '[69]', '[46]', '[53]', '[58]', '[48]', '[64]', '[46, 62, 53, 58, 48, 64]', '[62]', '[64]', '[55]', '[48]', '[60]', '[64, 60, 69]', '[55]', '[69]', '[60]', '[69, 70]', '[70]', '[69]', '[48, 55, 60, 70, 41, 72]', '[41]', '[72]', '[70]', '[72]', '[48]', '[41]', '[48]', '[53]', '[65]', '[72, 53, 65]', '[64]', '[65, 64]', '[65]', '[53]', '[45]', '[41, 48, 53, 64, 45, 65, 65]', '[64]', '[65]', '[52]', '[53]', '[45]', '[57]', '[65, 57, 72]', '[72]', '[52]', '[57]', '[72]', '[46]', '[72]', '[72, 45, 53, 57, 46, 72]', '[46]', '[53]', '[72]', '[72, 74]', '[74]', '[53]', '[74, 58, 70]', '[58]', '[70]', '[74]', '[58]', '[70, 69]', '[69]', '[70]', '[46, 53, 58, 69, 48, 70]', '[70]', '[47]', '[69]', '[47]', '[55]', '[70]', '[55]', '[60]', '[69]', '[70, 60, 69]', '[60]', '[69, 70]', '[70]', '[69]', '[48, 55, 60, 70, 41, 72]', '[41]', '[72]', '[70]', '[72]', '[48]', '[41]', '[72, 77]', '[77]', '[77, 53, 76]', '[76]', '[53]', '[77]', '[48]', '[77]', '[76, 77]', '[76]', '[53]', '[41, 48, 53, 77, 45, 72]', '[45]', '[71]', '[72]', '[77]', '[72]', '[45]', '[52]', '[53]', '[71]', '[72, 77]', '[77]', '[57]', '[76]', '[77, 57, 76]', '[52]', '[77]', '[57]', '[76, 77]', '[76]', '[46]', '[45, 53, 57, 77, 46, 72]', '[74]', '[77]', '[46]', '[53]', '[58]', '[74]', '[48]', '[76]', '[46, 72, 53, 58, 48, 74]', '[55]', '[48]', '[55]', '[74, 60, 76]', '[60]', '[55]', '[76, 48, 55, 60, 38, 77]', '[76]', '[60]', '[77]', '[38]']
# ==================================================
# ['[69]', '[69, 70]', '[70, 41, 72]', '[48]', '[72, 53, 65]', '[65, 64]', '[41, 48, 53, 64, 45, 65]', '[53]', '[65, 57, 72]', '[45, 53, 57, 72, 46, 72]', '[53]', '[72, 74]', '[74, 58, 70]', '[70, 69]', '[46, 53, 58, 69, 48, 70]', '[55]', '[70, 60, 69]', '[69, 70]', '[48, 55, 60, 70, 41, 72]', '[48]', '[72, 53, 65]', '[65, 64]', '[41, 48, 53, 64, 45, 65]', '[53]', '[65, 57, 69]', '[45, 53, 57, 69, 46, 62]', '[53]', '[58]', '[46, 62, 53, 58, 48, 64]', '[55]', '[64, 60, 69]', '[69, 70]', '[48, 55, 60, 70, 41, 72]', '[48]', '[72, 53, 65]', '[65, 64]', '[41, 48, 53, 64, 45, 65]', '[53]', '[65, 57, 72]', '[45, 53, 57, 72, 46, 72]', '[53]', '[72, 74]', '[74, 58, 70]', '[70, 69]', '[46, 53, 58, 69, 48, 70]', '[55]', '[70, 60, 69]', '[69, 70]', '[48, 55, 60, 70, 41, 72]', '[48]', '[72, 77]', '[77, 53, 76]', '[76, 77]', '[41, 48, 53, 77, 45, 72]', '[53]', '[72, 77]', '[77, 57, 76]', '[76, 77]', '[45, 53, 57, 77, 46, 72]', '[53]', '[58]', '[46, 72, 53, 58, 48, 74]', '[55]', '[74, 60, 76]', '[48, 55, 60, 76, 38, 77]', '[77]', '[38]']

# %% [markdown]
# # 음정비교
#
# ## 방법 2
#
# 점수 = 정확히 친 개수 / 총 쳐야하는 노트의 수 x 100

# %%
import pandas as pd

# 데이터 불러오기 및 전처리

input_path = './butterfly_input_data.csv'
target_path = './butterfly_target_data.csv'

input_data = pd.read_csv(input_path)
target_data = pd.read_csv(target_path)

# 중복 열 제거
def ridOfDupRow(midiData):
    for i in range(len(midiData)-1):
        if midiData['note'][i] == midiData['note'][i+1] or midiData['msg_type'][i] == '[]':
            midiData = midiData.drop(i)
    return midiData

# 확인
input_data = ridOfDupRow(input_data)
target_data = ridOfDupRow(target_data)
